# %%
import pandas as pd
from pycaret.classification import *
import random as r

# %%
training_data = pd.read_csv('train_data.csv')
testing_data = pd.read_csv('test_data.csv')
training_data = training_data.iloc[:, 1:]
training_data.describe()
# Out:
#                  f1            f2            f3            f4            f5  \
# count  23999.000000  23999.000000  23999.000000  23999.000000  23999.000000
# mean       0.468707      0.457409      0.482216      0.445491      0.510032
# std        0.133171      0.097082      0.114720      0.110729      0.112435
# min        0.020040      0.073640      0.096520      0.054510      0.059410
# 25%        0.375055      0.391935      0.402850      0.370665      0.436440
# 50%        0.468620      0.457510      0.479780      0.445100      0.513870
# 75%        0.561385      0.522230      0.557325      0.519295      0.587645
# max        0.969750      1.000000      0.908310      0.931690      0.969410
#
#                  f6            f7            f8            f9           f10  \
# count  23999.000000  23999.000000  23999.000000  23999.000000  23999.000000
# mean       0.484932      0.525397      0.558937      0.515624      0.468441
# ...

# %%
boolean_values = [True, False]
normalize_method = {'zscore', 'minmax', 'maxabs', 'robust'}
feature_selection_method = {'classic', 'boruta'}
# feature_selection_threshold = 0.2
# outliers_threshold = 0.05
# transformation = True, transformation_method = 'yeo-johnson',
#pca = True, pca_method = 'linear',
iterations = 500
min_accuracy = 0.5453
preprocess = 0
table = 0
parameters = 0

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/jaskaran/Desktop/ml-test-evaluation/random_preprocessing.ipynb Cell 4' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/jaskaran/Desktop/ml-test-evaluation/random_preprocessing.ipynb#ch0000011?line=0'>1</a> table
#
# NameError: name 'table' is not defined

# %%
bool_normalize = r.sample([True,False], 1)[0]
bool_normalize
# Out:
# False

# %%
for i in range(iterations):
    ans = [r.sample(boolean_values,1)[0] , r.uniform(0,0.06) ,r.sample([True,False],1)[0], r.sample(normalize_method,1)[0], r.sample(boolean_values,1)[0], r.sample(feature_selection_method,1)[0],
    r.uniform(0,0.5),   r.sample(boolean_values,1)[0], r.sample(boolean_values,1)[0]]
    # bool_normalize = r.sample([True,False], 1)
    # bool_transform = r.sample([True,False], 1)
    # ans[2] = bool_normalize
    # ans[7] = bool_transform
    s = setup(data= training_data, target='target', remove_outliers=ans[0], outliers_threshold=ans[1], normalize=ans[2], normalize_method=ans[3] ,
    feature_selection=ans[4], feature_selection_method=ans[5], feature_selection_threshold=ans[6], transformation=ans[7], pca=ans[8] ,silent=True)
    print(i)
    cm = compare_models(include=['qda','lr','lda','ridge','nb'])
    data= pull()
    if data.iloc[0,1] > min_accuracy:
        min_accuracy = data.iloc[0,1]
        table = data
        parameters = ans
# Out:
# <style type="text/css">
# #T_fa5cc th {
#   text-align: left;
# }
# #T_fa5cc_row0_col0, #T_fa5cc_row0_col2, #T_fa5cc_row0_col3, #T_fa5cc_row0_col5, #T_fa5cc_row0_col6, #T_fa5cc_row0_col7, #T_fa5cc_row1_col0, #T_fa5cc_row1_col1, #T_fa5cc_row1_col4, #T_fa5cc_row2_col0, #T_fa5cc_row2_col1, #T_fa5cc_row2_col2, #T_fa5cc_row2_col3, #T_fa5cc_row2_col4, #T_fa5cc_row2_col5, #T_fa5cc_row2_col6, #T_fa5cc_row2_col7, #T_fa5cc_row3_col0, #T_fa5cc_row3_col1, #T_fa5cc_row3_col2, #T_fa5cc_row3_col3, #T_fa5cc_row3_col4, #T_fa5cc_row3_col5, #T_fa5cc_row3_col6, #T_fa5cc_row3_col7, #T_fa5cc_row4_col0, #T_fa5cc_row4_col1, #T_fa5cc_row4_col2, #T_fa5cc_row4_col3, #T_fa5cc_row4_col4, #T_fa5cc_row4_col5, #T_fa5cc_row4_col6, #T_fa5cc_row4_col7 {
#   text-align: left;
# }
# #T_fa5cc_row0_col1, #T_fa5cc_row0_col4, #T_fa5cc_row1_col2, #T_fa5cc_row1_col3, #T_fa5cc_row1_col5, #T_fa5cc_row1_col6, #T_fa5cc_row1_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# ...

# %%
iterations
# Out:
# 500

# %%
s = setup(data= training_data, target='target', silent=True)
# Out:
# <style type="text/css">
# #T_51f6d_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_51f6d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_51f6d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_51f6d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_51f6d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_51f6d_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_51f6d_row0_col1" class="data row0 col1" >2708</td>
#     </tr>
#     <tr>
#       <th id="T_51f6d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_51f6d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_51f6d_row1_col1" class="data row1 col1" >target</td>
#     </tr>
#     <tr>
#       <th id="T_51f6d_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
cm = compare_models(include=['qda', 'lr'])
# Out:
# <style type="text/css">
# #T_ff66a th {
#   text-align: left;
# }
# #T_ff66a_row0_col0, #T_ff66a_row1_col0, #T_ff66a_row1_col1, #T_ff66a_row1_col2, #T_ff66a_row1_col3, #T_ff66a_row1_col4, #T_ff66a_row1_col5, #T_ff66a_row1_col6, #T_ff66a_row1_col7 {
#   text-align: left;
# }
# #T_ff66a_row0_col1, #T_ff66a_row0_col2, #T_ff66a_row0_col3, #T_ff66a_row0_col4, #T_ff66a_row0_col5, #T_ff66a_row0_col6, #T_ff66a_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ff66a_row0_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_ff66a_row1_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ff66a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff66a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ff66a_level0_col1" class="col_heading level0 col1" >Accuracy</th>
# ...

# %%
data = pull()

# %%
data.iloc[0,1]
# Out:
# 0.5344

# %%
data
# Out:
#                                Model  Accuracy     AUC  Recall   Prec.  \
# qda  Quadratic Discriminant Analysis    0.5344  0.5453  0.5408  0.5292
# lr               Logistic Regression    0.5272  0.5388  0.4862  0.5243
#
#          F1   Kappa     MCC  TT (Sec)
# qda  0.5349  0.0689  0.0689     0.608
# lr   0.5044  0.0537  0.0539     0.933
